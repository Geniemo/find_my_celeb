# %% [markdown]
# # 필요한 라이브러리들 import

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import os
import shutil
from libs.bing_image_downloader.bing_image_downloader import downloader

# %% [markdown]
# # 데이터셋 적재, 테스트 셋 분리

# %%
directory_list = [
    os.path.join('dataset', 'boy', 'train'),
    os.path.join('dataset', 'boy', 'test'),
]

# %%
# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, test_ratio):
    # 초기 디렉토리 안으로 들어가 평가,학습 디렉토리 생성
    for directory in directory_list:
        if not os.path.isdir(os.path.join(directory, query)):
            os.mkdir(os.path.join(directory, query))
    # 학습 및 평가 데이터셋 준비하기
    train_cnt = len(os.listdir(query)) * test_ratio
    cnt = 0
    # 디렉토리에 있는 파일을 shutil.move로 새로운 폴더로 옮긴 후 원래 있던 폴더 삭제
    for filename in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {filename}')
            shutil.move(os.path.join(query, filename), os.path.join(directory_list[0], filename))
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(os.path.join(query, filename), os.path.join(directory_list[1], filename))
        cnt += 1
    shutil.rmtree(query)

# %%
query_list = ['박보검', '송중기', '차은우', '현빈', '김수현', '류준열', '박서준', '공유', '이병헌', '정우성']
for query in query_list:
    downloader.download(query, limit=1000,  output_dir=os.path.join('dataset', 'boy', 'full'), 
                        adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to C:\Users\jiweo\jupyter\find_my_celeb\dataset\boy\full\박보검
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 154 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/6f/9e/20/6f9e200168ee03b5b97fc220f6c631d1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/58/03/c0/5803c04fcdb1e42166bdd03d3e9081ed.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/3b/3e/c3/3b3ec34ade402e2fc217df7d32fe5551.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/a3/0f/b9/a30fb94ba1d1034081c18adcdc52fc3b.gif
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.bing.com/th/id/OGC.42d3836cfd4459046bed7e2d3ec69db0?pid=1.7&amp;rurl=https%3a%2f%2fi.pinimg.com%2foriginals%2fa3%2f0f%2fb9%2fa30fb94ba1d1034081c18adcdc52fc3b.gif&amp;ehk=fF494gEKk6M%2b9iBGV3FRqUubGTVEEIWt9vOio9k3qKs%3d
# ...

# %%
pwd
# Out:
# 'C:\\Users\\jiweo\\jupyter\\find_my_celeb'
