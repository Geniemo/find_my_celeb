# %% [markdown]
# # 필요한 라이브러리들 import

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import os
import shutil
from libs.bing_image_downloader.bing_image_downloader import downloader

# %% [markdown]
# # 데이터셋 적재, 테스트 셋 분리

# %%
directory_list = [
    os.path.join(os.curdir, 'dataset', 'boy', 'train'),
    os.path.join(os.curdir, 'dataset', 'boy', 'test'),
]

# %%
# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
    # 초기 디렉토리 안으로 들어가 평가,학습 디렉토리 생성
    for directory in directory_list:
        if not os.path.isdir(os.path.join(directory, query)):
            os.mkdir(os.path.join(directory, query))
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    # 디렉토리에 있는 파일을 shutil.move로 새로운 폴더로 옮긴 후 원래 있던 폴더 삭제
    for filename in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {filename}')
            shutil.move(os.path.join(os.curdir, query, filename), os.path.join(directory_list[0], filename))
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(os.path.join(os.curdir, query, filename), os.path.join(directory_list[1], filename))
        cnt += 1
    shutil.rmtree(query)

# %%
query_list = ['박보검', '송중기', '차은우', '현빈', '김수현', '류준열', '박서준', '공유', '이병헌', '정우성']
for query in query_list:
    downloader.download(query, limit=1000,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
    dataset_split(query, 800)
# Out:
# [%] Downloading Images to C:\Users\jiweo\jupyter\project\박보검
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 154 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/6f/9e/20/6f9e200168ee03b5b97fc220f6c631d1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.nemopan.com/files/attach/images/6294/158/258/010/d0aa1d6702e44f78ad38526904631e90.png
# [!] Issue getting: https://www.nemopan.com/files/attach/images/6294/158/258/010/d0aa1d6702e44f78ad38526904631e90.png
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)>
# [%] Downloading Image #2 from https://thumb.zumst.com/530x0/https://static.news.zumst.com/images/51/2020/06/02/0c9d6eb7cf7e478caa0f25d921a8a962.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.hanstar.net/news/data/20140224/p179516719110123_570.jpg
# [%] File Downloaded !
#
# ...
